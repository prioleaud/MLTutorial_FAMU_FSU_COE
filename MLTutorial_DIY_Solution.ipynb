# %% [markdown]
# # **Machine Learning Solution: FAMU-FSU COE Visit**
#
# ## **Running the notebook:**
#
# Problem Definition:
# The datasets consists of 10 features as described following:
#
# 1. Class: no-recurrence-events, recurrence-events
# 2. age: 10-19, 20-29, 30-39, 40-49, 50-59, 60-69, 70-79, 80-89, 90-99.
# 3. menopause: lt40, ge40, premeno.
# 4. tumor-size: 0-4, 5-9, 10-14, 15-19, 20-24, 25-29, 30-34, 35-39, 40-44, 45-49, 50-54, 55-59.
# 5. inv-nodes: 0-2, 3-5, 6-8, 9-11, 12-14, 15-17, 18-20, 21-23, 24-26, 27-29, 30-32, 33-35, 36-39.
# 6. node-caps: yes, no.
# 7. deg-malig: 1, 2, 3.
# 8. breast: left, right.
# 9. breast-quad: left-up, left-low, right-up,	right-low, central.
# 10. irradiat: yes, no.
#
# The task here is to use the attributes to predict if a tumor is none recurrent or recurrent events .
#
# You can find the dataset at the following link:
# https://archive.ics.uci.edu/ml/datasets/breast+cancer
#
# Like the tutorial, we will proceed with the following tasks:
#
# Step 1: Data Preparation
#
# Step 2: Data Exploration
#
# Step 3: Prediction of tumors
#
# Step 4: Metrics to Analyze the performance of your model

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import itertools
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#read our data first
data = pd.read_csv('data.csv')
#divide into labels and data 
labels = data.iloc[:,-1]
data =data.iloc[:,1:9]
# Out:
#     Menopause Tumor-size inv-nodes node-caps  deg-malig breast breast-quad  \
# 0     premeno      30-34       0-2        no          3   left    left_low
# 1     premeno      20-24       0-2        no          2  right    right_up
# 2     premeno      20-24       0-2        no          2   left    left_low
# 3        ge40      15-19       0-2        no          2  right     left_up
# 4     premeno        0-4       0-2        no          2  right   right_low
# 5        ge40      15-19       0-2        no          2   left    left_low
# 6     premeno      25-29       0-2        no          2   left    left_low
# 7        ge40      20-24       0-2        no          1   left    left_low
# 8     premeno      50-54       0-2        no          2   left    left_low
# 9     premeno      20-24       0-2        no          2  right     left_up
# 10    premeno        0-4       0-2        no          3   left     central
# 11       ge40      25-29       0-2        no          2   left    left_low
# 12       lt40     14-Oct       0-2        no          1   left    right_up
# 13       ge40      25-29       0-2        no          3   left    right_up
# 14    premeno      30-34       0-2        no          3   left     left_up
# 15       lt40      30-34       0-2        no          1   left    left_low
# 16    premeno      15-19       0-2        no          2   left    left_low
# 17    premeno      30-34       0-2        no          3   left    left_low
# 18       ge40      30-34       0-2        no          3   left    left_low
# 19       ge40      30-34       0-2        no          1  right    right_up
# 20       ge40      40-44       0-2        no          2   left    left_low
# 21       ge40      15-19       0-2        no          2   left    left_low
# 22    premeno      25-29       0-2        no          2  right    left_low
# 23    premeno      40-44       0-2        no          2   left     left_up
# 24    premeno      35-39       0-2        no          2  right     left_up
# 25    premeno      25-29       0-2        no          2   left     left_up
# 26    premeno      20-24       0-2        no          1   left    left_low
# 27       ge40      25-29       0-2        no          3  right     left_up
# 28    premeno      40-44       0-2        no          2  right    left_low
# 29       ge40      30-34       0-2        no          2   left    left_low
# ..        ...        ...       ...       ...        ...    ...         ...
# 256   premeno      30-34       0-2        no          1   left    left_low
# 257   premeno      20-24     5-Mar       yes          2   left    left_low
# 258      ge40      30-34     8-Jun       yes          2   left   right_low
# 259      ge40      30-34     5-Mar        no          3  right     left_up
# 260      ge40      25-29     5-Mar        no          2  right    right_up
# 261      ge40      25-29    14-Dec       yes          3   left   right_low
# 262      ge40      25-29       0-2        no          3   left     left_up
# 263      lt40      20-24       0-2         ?          1   left     left_up
# 264      lt40      20-24       0-2         ?          1   left    left_low
# 265   premeno      35-39    11-Sep       yes          3   left    left_low
# 266   premeno      30-34     5-Mar       yes          2   left    right_up
# 267      ge40      20-24     24-26       yes          3   left    left_low
# 268   premeno      35-39       0-2        no          3   left    left_low
# 269   premeno      25-29       0-2        no          2   left    left_low
# 270      ge40      30-34     8-Jun       yes          3   left   right_low
# 271   premeno      25-29       0-2        no          3  right    left_low
# 272   premeno      15-19       0-2       yes          3  right     left_up
# 273      ge40      30-34       0-2       yes          2  right    right_up
# 274      ge40      30-34     5-Mar       yes          2   left     central
# 275   premeno      25-29    11-Sep       yes          3  right     left_up
# 276   premeno      25-29     8-Jun       yes          3   left   right_low
# 277      ge40     14-Oct     8-Jun       yes          3   left     left_up
# 278   premeno      35-39     15-17       yes          3  right    right_up
# 279      ge40      40-44     8-Jun       yes          3   left    left_low
# 280      ge40      40-44     8-Jun       yes          3   left    left_low
# 281   premeno      30-34       0-2        no          2   left     left_up
# 282   premeno      20-24       0-2        no          3   left     left_up
# 283      ge40      20-24       0-2        no          1  right     left_up
# 284      ge40      30-34     5-Mar        no          3   left    left_low
# 285      ge40      30-34     5-Mar        no          3   left    left_low
#
#     irradiat
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# 5         no
# 6         no
# 7         no
# 8         no
# 9         no
# 10        no
# 11        no
# 12        no
# 13        no
# 14        no
# 15        no
# 16        no
# 17        no
# 18        no
# 19        no
# 20        no
# 21        no
# 22        no
# 23        no
# 24        no
# 25        no
# 26        no
# 27        no
# 28        no
# 29        no
# ..       ...
# 256      yes
# 257      yes
# 258      yes
# 259       no
# 260       no
# 261      yes
# 262       no
# 263       no
# 264       no
# 265       no
# 266       no
# 267      yes
# 268       no
# 269      yes
# 270       no
# 271      yes
# 272       no
# 273      yes
# 274      yes
# 275       no
# 276      yes
# 277      yes
# 278       no
# 279      yes
# 280      yes
# 281       no
# 282      yes
# 283       no
# 284       no
# 285       no
#
# [286 rows x 8 columns]

# %%
#data exploration and visualization
data.head()
#calculate the summary statistics, Note that some columns cannot be summarised as there is no logical way to summarise them, 
#for instance columns containing string data
data.describe()
# Out:
#         deg-malig
# count  286.000000
# mean     2.048951
# std      0.738217
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %%
#prediction and cross validation

# %%
# assess the performance of the classification model
